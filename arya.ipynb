# %% [markdown]
# <a href="https://colab.research.google.com/github/gnishtha/Arya_assignment/blob/master/arya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/training_set.csv')

# %%
df.describe()
# Out:
#         Unnamed: 0           X1  ...           X57            Y
# count  3910.000000  3910.000000  ...   3910.000000  3910.000000
# mean   1954.500000     0.102990  ...    283.059079     0.392327
# std    1128.864105     0.296322  ...    578.339858     0.488331
# min       0.000000     0.000000  ...      1.000000     0.000000
# 25%     977.250000     0.000000  ...     35.000000     0.000000
# 50%    1954.500000     0.000000  ...     94.000000     0.000000
# 75%    2931.750000     0.000000  ...    264.000000     1.000000
# max    3909.000000     4.340000  ...  10062.000000     1.000000
#
# [8 rows x 59 columns]

# %%
cols=list(df.keys())
cols
# Out:
# ['Unnamed: 0',
#  'X1',
#  'X2',
#  'X3',
#  'X4',
#  'X5',
#  'X6',
#  'X7',
#  'X8',
#  'X9',
#  'X10',
#  'X11',
#  'X12',
#  'X13',
#  'X14',
#  'X15',
#  'X16',
#  'X17',
#  'X18',
#  'X19',
#  'X20',
#  'X21',
#  'X22',
#  'X23',
#  'X24',
#  'X25',
#  'X26',
#  'X27',
#  'X28',
#  'X29',
#  'X30',
#  'X31',
#  'X32',
#  'X33',
#  'X34',
#  'X35',
#  'X36',
#  'X37',
#  'X38',
#  'X39',
#  'X40',
#  'X41',
#  'X42',
#  'X43',
#  'X44',
#  'X45',
#  'X46',
#  'X47',
#  'X48',
#  'X49',
#  'X50',
#  'X51',
#  'X52',
#  'X53',
#  'X54',
#  'X55',
#  'X56',
#  'X57',
#  'Y']

# %%
X_df=df[cols[:-1]]
y_df=df[cols[-1]]

# %%
X_df.head()
# Out:
#    Unnamed: 0    X1    X2    X3     X4  ...    X53    X54     X55  X56  X57
# 0           0  0.00  0.00  4.34   0.00  ...  0.000  0.000   1.200    2   12
# 1           1  0.00  0.56  0.56   0.00  ...  0.000  0.083  16.304  148  375
# 2           2  0.00  0.00  0.00   0.00  ...  0.000  0.000   1.000    1    5
# 3           3  0.64  0.00  0.64   0.00  ...  0.370  0.000   2.440   22  122
# 4           4  0.58  0.00  0.00  35.46  ...  0.239  0.000   3.338  123  207
#
# [5 rows x 58 columns]

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(11,8))
ax1 = fig.add_subplot(111)

ax1.plot(X_df['X3'], label='visualising deviation', color='c', marker='o')
#plt.xticks(df.year.unique())
plt.xlabel('x')
plt.ylabel('y')

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)


handles, labels = ax1.get_legend_handles_labels()
lgd = ax1.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.15,1))

plt.show('smooth_plot.png')

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans
import sklearn.metrics as sm
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import scipy
from sklearn import decomposition

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.10, random_state=42)

# %%
#good Training Accuracy
rfc = RandomForestClassifier(max_depth=2, random_state=0)
rfc.fit(X_train, y_train)
rfc.score(X_train, y_train)
# Out:
# 0.887468030690537

# %%
#good validation Accuracy
y_pred=rfc.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8900255754475703

# %%
#High Training Accuracy
clf = SVC(gamma='auto')
clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 0.9991474850809889

# %%
#low validation Accuracy

y_pred=clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6317135549872123

# %%
#So the better model is Random forest, So lets check if PCA can further improve it
pca = decomposition.PCA(n_components=25)
pca.fit(X_train)
x = pca.transform(X_train)
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(x, y_train)
clf.score(x, y_train)
# Out:
# 0.8422847399829497

# %%
#PCA has further reduced the accuracy
y_pred=clf.predict(pca.transform(X_test))
accuracy_score(y_test, y_pred)
# Out:
# 0.8286445012787724

# %%
test_df=pd.read_csv('/content/test_set.csv')
test_df.head()
# Out:
#    Unnamed: 0    X1   X2    X3   X4  ...    X53    X54     X55  X56   X57
# 0           0  0.70  0.0  0.70  0.0  ...  0.000  0.000   2.342   47    89
# 1           1  0.00  0.0  0.84  0.0  ...  0.129  0.000  10.375  168   249
# 2           2  0.46  0.3  0.46  0.0  ...  0.756  0.153   5.891  193  3040
# 3           3  0.10  0.2  1.01  0.0  ...  0.158  0.015   8.550  669  1351
# 4           4  0.00  0.0  0.72  0.0  ...  0.121  0.000   7.781   32   249
#
# [5 rows x 58 columns]

# %%
#Using Random forest due to high validation accuracy
y_pred=rfc.predict(test_df)
pd.DataFrame(y_pred).to_csv('result.csv')
